# %%
# Public Data Application Programming Interface (API)
# https://www.bls.gov/bls/api_features.htm
# https://www.bls.gov/developers/api_python.htm#python2
# https://www.bls.gov/developers/api_signature_v2.htm#python2

# %%
# write to txt files
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2011", "endyear":"2014"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()

# %%
# print pandas table
import pandas as pd
import requests
import json
import os

headers = {'Content-type': 'application/json'}
data = json.dumps(
        {
        "seriesid": ['LNU02000000'], # (Seas) Employment Level
        "startyear":"1947", 
        "endyear":"2023",
        "registrationkey": os.environ['API_TOKEN_US_BUREAU_OF_LABOR_STATISTICS']
        }
    )
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)

json_ts = json_data['Results']['series'][0]['data']
json_ts

df = pd.DataFrame(json_ts)
df
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'API_TOKEN_US_BUREAU_OF_LABOR_STATISTICS': '61a94d6a16714a36a4dd79976b1f9a0f', 'APPDATA': 'C:\\Users\\chris\\AppData\\Roaming', 'ASL.LOG': 'Destination=file', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '133243069813762472', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_7816_GXHFOUUNEBDOMLWD', 'CLASSPATH': '.;', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'XMG', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_ALLOW_SOFTLINKS': 'false', 'CONDA_DEFAULT_ENV': 'oil-price-prediction', 'CONDA_EXE': 'C:\\ProgramData\\anaconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'C:\\Users\\chris\\.conda\\envs\\oil-price-prediction', 'CONDA_PROMPT_MODIFIER': '(oil-price-prediction) ', 'CONDA_PYTHON_EXE': 'C:\\ProgramData\\anaconda3\\python.exe', 'CONDA_ROOT': 'C:\\ProgramData\\anaconda3', 'CONDA_SHLVL': '1', 'CUDA_PATH': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.7', 'CUDA_PATH_V11_0': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.0', 'CUDA_PATH_V11_1': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.1', 'CUDA_PATH_V11_7': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.7', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_11576': '1', 'ELECTRON_RUN_AS_NODE': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\chris', 'JAVA_HOME': 'C:\\Program Files\\Java\\jdk1.8.0_211', 'JPY_INTERRUPT_EVENT': '1784', 'LOCALAPPDATA': 'C:\\Users\\chris\\AppData\\Local', 'LOGONSERVER': '\\\\XMG', 'NUMBER_OF_PROCESSORS': '16', 'NVCUDASAMPLES11_0_ROOT': 'C:\\ProgramData\\NVIDIA Corporation\\CUDA Samples\\v11.0', 'NVCUDASAMPLES11_1_ROOT': 'C:\\ProgramData\\NVIDIA Corporation\\CUDA Samples\\v11.1', 'NVCUDASAMPLES_ROOT': 'C:\\ProgramData\\NVIDIA Corporation\\CUDA Samples\\v11.0', 'NVTOOLSEXT_PATH': 'C:\\Program Files\\NVIDIA Corporation\\NvToolsExt\\', 'ONEDRIVE': 'C:\\Users\\chris\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\chris\\.conda\\envs\\oil-price-prediction;C:\\Users\\chris\\.conda\\envs\\oil-price-prediction;C:\\Users\\chris\\.conda\\envs\\oil-price-prediction\\Library\\mingw-w64\\bin;C:\\Users\\chris\\.conda\\envs\\oil-price-prediction\\Library\\usr\\bin;C:\\Users\\chris\\.conda\\envs\\oil-price-prediction\\Library\\bin;C:\\Users\\chris\\.conda\\envs\\oil-price-prediction\\Scripts;C:\\Users\\chris\\.conda\\envs\\oil-price-prediction\\bin;C:\\ProgramData\\anaconda3\\condabin;C:\\Python310\\Scripts;C:\\Python310;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.7\\bin;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.7\\libnvvp;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.0\\bin;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.0\\libnvvp;C:\\Program Files\\Python38\\Scripts;C:\\Program Files\\Python38;C:\\Python39\\Scripts;C:\\Python39;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.1\\bin;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.1\\libnvvp;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Program Files (x86)\\Common Files\\Acronis\\VirtualFile;C:\\Program Files (x86)\\Common Files\\Acronis\\VirtualFile64;C:\\Program Files (x86)\\Common Files\\Acronis\\FileProtector;C:\\Program Files (x86)\\Common Files\\Acronis\\FileProtector64;C:\\Program Files (x86)\\Common Files\\Acronis\\SnapAPI;C:\\Program Files\\Java\\jdk1.8.0_211\\bin;C:\\Program Files\\PuTTY;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\Syste ...
# 61a94d6a16714a36a4dd79976b1f9a0f
#      year period periodName  value footnotes
# 0    1966    M12   December  73600      [{}]
# 1    1966    M11   November  73995      [{}]
# 2    1966    M10    October  73744      [{}]
# 3    1966    M09  September  73248      [{}]
# 4    1966    M08     August  74665      [{}]
# ..    ...    ...        ...    ...       ...
# 223  1948    M05        May  57763      [{}]
# 224  1948    M04      April  57471      [{}]
# 225  1948    M03      March  56601      [{}]
# 226  1948    M02   February  56440      [{}]
# 227  1948    M01    January  56339      [{}]
#
# [228 rows x 5 columns]

# %%
# print pandas table
import pandas as pd
import requests
import json
import os

def check_date_range(startyear, endyear):
    year_diff = int(endyear) - int(startyear)
    if year_diff > 20:
        raise Exception('Registered users may request up to 20 years per query.')

def get_bls_data(seriesid, startyear, endyear):
    check_date_range(startyear, endyear)
    filename = 'cache/'+seriesid+'/startyear'+startyear+'_endyear'+endyear+'.json'
    if os.path.isfile(filename):
        with open(filename) as json_file:
            json_data = json.load(json_file)
            return json_data

    headers = {'Content-type': 'application/json'}
    data = json.dumps(
            {
            "seriesid": [seriesid],
            "startyear": startyear, 
            "endyear": endyear,
            "registrationkey": os.environ['API_TOKEN_US_BUREAU_OF_LABOR_STATISTICS']
            }
        )
    p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
    json_data = json.loads(p.text)

    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, 'w') as f:
        f.write(json.dumps(json_data))

    return json_data


get_bls_data('LNU02000000', '2003', '2023')
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 231,
#  'message': ['Year range has been reduced to the system-allowed limit of 20 years.'],
#  'Results': {'series': [{'seriesID': 'LNU02000000',
#     'data': [{'year': '2022',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '158872',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '158749',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '159144',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '159003',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '158714',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '159067',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '158678',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '158609',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '157991',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '158106',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '156942',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '155618',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2021',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '155732',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '155797',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '154966',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '154026',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '153232',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '153596',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '152283',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '151778',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '151160',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '150493',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '149522',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '148383',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2020',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '149613',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '150203',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '150433',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '147796',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '147224',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '144492',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '142811',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '137461',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '133326',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '155167',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '158017',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '156994',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '158504',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '158945',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '159067',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '158478',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '157816',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '158385',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '157828',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '157152',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '156710',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '156441',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '156167',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '154964',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '156481',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '157015',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '156952',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '156191',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '155539',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '157004',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '156465',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '156009',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '155348',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '154877',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '154403',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '152848',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '153602',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '154180',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '154223',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '154494',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '153576',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '154470',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '154086',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '153407',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '153262',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '152628',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '151594',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '150527',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '151798',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '152385',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '152335',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '151977',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '151804',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '152437',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '151990',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '151594',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '151075',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '150738',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '150060',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '149037',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '149703',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '149766',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '149716',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '148980',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '149228',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '149722',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '149645',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '149349',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '148587',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '147635',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '147118',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '146552',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '147190',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '147666',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '147936',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '146941',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '146647',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '147265',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '147104',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '146398',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '145767',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '145090',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '144134',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '143526',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '144423',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '144775',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '144144',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '144651',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '144509',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '145113',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '144841',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '144432',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '143724',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '142698',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '142228',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '141614',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '143060',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '143549',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '144039',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '143333',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '142558',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '143126',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '143202',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '142727',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '141995',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '141412',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '140684',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '139944',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '140681',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '141070',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '140987',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '140502',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '140335',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '140384',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '140129',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '140028',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '139661',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '138962',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '138093',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '137599',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2010',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '139159',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '139415',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '139749',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '139715',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '139919',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '140134',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '139882',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '139497',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '139302',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '137983',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '137203',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '136809',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2009',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '137953',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '139132',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '139088',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '139079',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '140074',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '141055',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '140826',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '140363',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '140586',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '139833',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '140105',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '140436',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2008',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '143350',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '144609',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '145543',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '145310',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '145909',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '146867',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '146649',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '145927',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '145921',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '145108',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '144550',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '144607',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2007',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '146334',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '147118',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '146743',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '146448',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '146406',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '147315',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '146958',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '145864',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '145297',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '145323',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '144479',
#       'footnotes': [{}]},
#      {'year': '2007',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '144275',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2006',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '146081',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '146014',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '146125',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '145010',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '145379',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '145606',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '145216',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '144041',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '143405',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '142772',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '141994',
#       'footnotes': [{}]},
#      {'year': '2006',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '141481',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2005',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '142918',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '142968',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '143340',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '142579',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '143142',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '143283',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '142456',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '141591',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '140939',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '139759',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '139100',
#       'footnotes': [{}]},
#      {'year': '2005',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '138682',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2004',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '140278',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '140581',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '140447',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '139641',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '140226',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '140700',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '139861',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '138867',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '138423',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '137691',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '137384',
#       'footnotes': [{}]},
#      {'year': '2004',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '136924',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]},
#      {'year': '2003',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '138556',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '138700',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '138619',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '137731',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '138137',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '138503',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '138468',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '137567',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '137424',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '136783',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '136433',
#       'footnotes': [{}]},
#      {'year': '2003',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '135907',
#       'footnotes': [{'code': '1',
#         'text': 'Data affected by changes in population controls.'}]}]}]}}

# %%
from BlsGov import BlsGov

bls_gov = BlsGov()
bls_gov.get_data('LNU02000000', '2003', '2023')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\chris\Project\Oil-Price-Prediciton\data-sources\us_bureau_of_labor_statistics\examples.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/chris/Project/Oil-Price-Prediciton/data-sources/us_bureau_of_labor_statistics/examples.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from BlsGov import BlsGov
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chris/Project/Oil-Price-Prediciton/data-sources/us_bureau_of_labor_statistics/examples.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> BlsGov().get_data('LNU02000000', '2003', '2023')
#
# AttributeError: 'BlsGov' object has no attribute 'get_data'
